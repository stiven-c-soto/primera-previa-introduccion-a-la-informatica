# %%
print ("hello my name is Stiven")
# Out:
# hello my name is Stiven

# %%
nombre = "stiven" 
print (nombre)
# Out:
# stiven

# %%
nombre = "stiven  castro"
print (nombre)
# Out:
# stiven  castro

# %%
nombre = "stiven castro" #esto es un comentario
print (nombre.title())
# Out:
# Stiven Castro

# %%
nombre = "stiven castro"
print (nombre.upper())   
print (nombre.lower())
# Out:
# STIVEN CASTRO
# stiven castro

# %%
primer= "introduccion"
segundo = "informatica"
completo = primer + " a la " + segundo
print(completo)
# Out:
# introduccion a la informatica

# %%
print ("hola")
print ("\thola")
print ("\t1")
print ("1")
# Out:
# hola
# 	hola
# 	1
# 1

# %%
print ("nombres: stiven \napellidos: castro soto \nsemestre: 1 \nmateria: introduccion a la informatica")
# Out:
# nombres: stiven
# apellidos: castro soto
# semestre: 1
# materia: introduccion a la informatica

# %%
print ("nombres: \n\tstiven \napellidos: \n\tcastro soto \nsemestre: \n\t1 \nmateria: \n\tintroduccion a la informatica")
# Out:
# nombres:
# 	stiven
# apellidos:
# 	castro soto
# semestre:
# 	1
# materia:
# 	introduccion a la informatica

# %%
lenguaje_1 = "python   "
lenguaje_2 = "     python"

print ("Sin eliminar los espacios")
print ()
print (lenguaje_1)
print (lenguaje_2)
print ()
print ("Eliminando los espacios")
print ()
print (lenguaje_1.rstrip()) #elimina a la derecha
print (lenguaje_2.lstrip()) #elimina a la izquierda
# Out:
# Sin eliminar los espacios
#
# python
#      python
#
# Eliminando los espacios
#
# python
# python

# %%
print (2 + 3)
print (3 - 2)
print (2 * 3)
print (3 / 2)

suma = 3 + 2
mult = 3 * 2
resta = 3 - 2
div = 3 / 2

print ()
print (suma)
print (resta)
print (mult)
print (div)
# Out:
# 5
# 1
# 6
# 1.5
#
# 5
# 1
# 6
# 1.5

# %%
potencia = 3 ** 2 #al cuadrado
potencia2 = 3 ** 3 #al cubo
print (potencia)
print (potencia2)
# Out:
# 9
# 27

# %%
print (2 + 3*4)
print ( (2 + 3) * 4)

suma_mult = 2 + 3*4
suma_mult_or = (2 + 3) * 4

print ()
print (suma_mult)
print (suma_mult_or)
# Out:
# 14
# 20
#
# 14
# 20

# %%
print (0.1 + 0.1)
print (0.2 + 0.2)
print (2 * 0.1)
print (2 * 0.2)
decimal = 2 * 0.2

print (decimal)

print (0.2 + 0.1)
print (3 * 0.1)
# Out:
# 0.2
# 0.4
# 0.2
# 0.4
# 0.4
# 0.30000000000000004
# 0.30000000000000004

# %%
edad = 24
sem = 1
año = 2021
print ("La edad de Juan es de " + str(edad) + " años")
print ()
print ("estamos en el semestre " + str(sem) + " del " + str(año))
# Out:
# La edad de Juan es de 24 años
#
# estamos en el semestre 1 del 2021

# %%
x = 10
x = x * 20.0
print (x)
# Out:
# 200.0

# %%
cadena1 = "esta es la prueba"
cadena2 = " de cadenas"
prueba = cadena1 + cadena2
print (prueba)
# Out:
# esta es la prueba de cadenas

# %%
print (prueba[10:17]) # el primer caracter es el cero
# Out:
#  prueba

# %%
registro = ('Salgado', 'Juan', (15,3,85))   # Esta es una tupla
apellido, nombre, nacimiento = registro     # Desempaqueta la tupla

print(apellido)
print(nombre)

año = nacimiento[2]   # Tercera posición en la tupla
mes = nacimiento[1]   # Segunda posición en la tupla
dia = nacimiento[0]   # Primera posición en la tupla

print(año)
print(mes)
print(dia)

registro2 = ('Salgado', 'Juan', (15,3,85))   # Esta es una tupla
registro2 = apellido, nombre, nacimiento      # Desempaqueta la tupla

print(apellido)
print(nombre)

año = nacimiento[2]   # Tercera posición en la tupla
mes = nacimiento[1]   # Segunda posición en la tupla
dia = nacimiento[0]   # Primera posición en la tupla

print(año)
print(mes)
print(dia)
# Out:
# Salgado
# Juan
# 85
# 3
# 15
# Salgado
# Juan
# 85
# 3
# 15

# %%
a = [1 , 2 , 3 , 4] #se crea una lista
print (a)
# Out:
# [1, 2, 3, 4]

# %%
a.append(5) #se agrega un elemento a la lista en la ultima posicion
print (a)
# Out:
# [1, 2, 3, 4, 5]

# %%
a.insert(2, 2.1) #inserta un elemento a la lista en la posicion que se indique antes del , y despues se coloca lo que se quiere insertar 
print (a)
# Out:
# [1, 2, 2.1, 3, 4, 5]

# %%
print (len(a)) #imprime la longitud o cuantos elementos tiene  la lista
print (len(registro2))
# Out:
# 6
# 3

# %%
# Se modifican los elementos seleccionados
a[2:4] = [7.0, 7.0]
print(a)
# Out:
# [1, 2, 7.0, 7.0, 4, 5]

# %%
# Se crea un 'alias' para la lista a
b = a

# Se modifica el primer elemento utilizando el nombre b
b[0] = 5.0

# Ahora se imprime la lista a. Como se ve, la lista a, ha sido modificada
print(a)
# Out:
# [5.0, 2, 7.0, 7.0, 4, 5]

# %%
a = [1.0, 2.0, 3.0]
c = a[:] # se crea una copia independiente de la lista a

c[0] = 5.0

# La lista original se mantiene igual
print(a)

# La lista c ha sido modificada en su primer valor
print(c)
# Out:
# [1.0, 2.0, 3.0]
# [5.0, 2.0, 3.0]

# %%
a = [[1, 2, 3], \
     [4, 5, 6], \
     [7, 8, 9]]

# El símbolo \ es un carácter de continuación. En este caso, podría omitirse

print(a)
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
# Accediendo a las filas de la matriz

print(a[0])   # Escribe la primera fila
print(a[1])   # Escribe la segunda fila
print(a[2])   # Escribe la tercera fila
# Out:
# [1, 2, 3]
# [4, 5, 6]
# [7, 8, 9]

# %%
# Accediendo a elementos individuales
print(a[1][2])    # Imprime el elemento de la primera fila en la segunda columna
# Out:
# 6
